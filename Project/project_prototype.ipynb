# %%
from langchain_aws.agents.base import BedrockAgentsRunnable
from langchain.schema.messages import AIMessage, HumanMessage
from langchain_community.tools import DuckDuckGoSearchResults
from langchain_aws.agents.base import BedrockAgentsRunnable
from langchain.agents import Tool, AgentExecutor
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from importlib import reload
import config as conf
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langsmith import traceable
import boto3

# !export LANGCHAIN_TRACING_V2=true
# !export LANGCHAIN_API_KEY=conf.langsmith_api

# %%
search = DuckDuckGoSearchResults()

# %%
region_name = 'us-east-1'
bedrock_agent = boto3.client(service_name = 'bedrock-agent-runtime', region_name = region_name)

# %%
bedrock_agent = BedrockAgentsRunnable(
    agent_id="JQNNUTIFGE", 
    agent_alias_id="ADSXXXOCVK",
    client=bedrock_agent
)

# %%
chat_history = []

# %%
@tool
@traceable
def interact_with_agent(input_query, chat_history):
    """Interact with the agent and store chat history. Return the response.
    When communicating with the main agent always call this tool with the exception of looking for the video."""
    result = bedrock_agent.invoke(
        {
            "input": input_query,
            "chat_history": chat_history,
        }
    )
    print(result)
    chat_history.append(input_query)
    chat_history.append("Assistant: " + result.return_values['output'])
    return result


# Define a tool that uses the DuckDuckGoSearchResults tool
@tool
@traceable
def search_tool(input_data):
    """Searches for the youtube videos explaining the problem."""
    return search.run(input_data)


# # Human interaction tool (could be a simple input function or more complex UI)
# @tool
# def human_review(input_data):
#     print(f"Review the following data: {input_data}")
#     decision = input("Enter your decision (approve/modify): ")
#     if decision.lower() == 'modify':
#         modified_data = input("Enter the modified data: ")
#         return modified_data
#     return input_data

system_message = """You are a Teacher of preparation for the coding interview. You are preparing a student for the coding interview. 
When the student is communicating with you always call the interact_with_agent_tool with only one exception - when the student wants to find a video
with the explanation of the problem. In this case, call the search_tool.
When the user asks you to give the problem in specific topic - call interact_with_agent_tool with the user request as an input.
If the user asks you for a video - call the search_tool with the user request and problem as an input."""

model = ChatOpenAI(model="gpt-4o", openai_api_key=conf.open_ai_key)
app = create_react_agent(model, [interact_with_agent, search_tool], state_modifier=system_message,)

query = "Please explain linked lists to me"
message_history = []
@traceable
def pipeline(query, message_history):
    
    if len(message_history) > 1:
        history = [message['messages'] for message in message_history[-1:]]
    elif message_history == []:
        history = []
    else:
        history = message_history['messages']
    return app.invoke({"messages": history + [("human", query)]})

messages = pipeline(query, message_history)
message_history = messages
# Out:
# return_values={'output': 'A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.'} log='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.' session_id='83f1a098-6ec5-4077-94c2-503b9dd1622b'

# %%
messages
# Out:
# {'messages': [HumanMessage(content='Please explain linked lists to me', id='406464c1-a8f5-411c-aa2f-9d74260c1ce5'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'function': {'arguments': '{"input_query":"Please explain linked lists to me","chat_history":[]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 230, 'total_tokens': 256}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d525fab9-74c2-403a-bd07-ee8c91cd1fcc-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Please explain linked lists to me', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.']}, 'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 230, 'output_tokens': 26, 'total_tokens': 256}),
#   ToolMessage(content="return_values={'output': 'A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.'} log='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.' session_id='83f1a098-6ec5-4077-94c2-503b9dd1622b'", name='interact_with_agent', id='82d9635d-64b0-4d5e-a93b-6c2cbe8844bb', tool_call_id='call_P2gVcpaq5CkBD1QeQjpObCSw'),
#   AIMessage(content='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. **Data**: The value or information that the node stores.\n2. **Next**: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\n```python\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n```\n\nSome key operations on linked lists:\n- **Insertion**: Adding a new node at the beginning, end, or a specific position in the list.\n- **Deletion**: Removing a node from the beginning, end, or a specific position in the list.\n- **Traversal**: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 1066, 'total_tokens': 1313}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-bb0f2096-c8e8-416c-8ffd-4396e92d2adf-0', usage_metadata={'input_tokens': 1066, 'output_tokens': 247, 'total_tokens': 1313})]}

# %%
messages2 = pipeline('Give me a problem in linked lists', message_history)
# Out:
# return_values={'output': 'Could you please provide me with another linked list problem for a coding interview preparation? I would like the problem statement, examples of how it should work, and the necessary code definitions like the structure of a linked list node.'} log='Could you please provide me with another linked list problem for a coding interview preparation? I would like the problem statement, examples of how it should work, and the necessary code definitions like the structure of a linked list node.' session_id='c80e0373-0b21-4a97-85bd-91cf15ed4dc0'

# %%
message_history += messages2

# %%
messages2
# Out:
# {'messages': [HumanMessage(content='Please explain linked lists to me', id='406464c1-a8f5-411c-aa2f-9d74260c1ce5'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'function': {'arguments': '{"input_query":"Please explain linked lists to me","chat_history":[]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 230, 'total_tokens': 256}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d525fab9-74c2-403a-bd07-ee8c91cd1fcc-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Please explain linked lists to me', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.']}, 'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 230, 'output_tokens': 26, 'total_tokens': 256}),
#   ToolMessage(content="return_values={'output': 'A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.'} log='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.' session_id='83f1a098-6ec5-4077-94c2-503b9dd1622b'", name='interact_with_agent', id='82d9635d-64b0-4d5e-a93b-6c2cbe8844bb', tool_call_id='call_P2gVcpaq5CkBD1QeQjpObCSw'),
#   AIMessage(content='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. **Data**: The value or information that the node stores.\n2. **Next**: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\n```python\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n```\n\nSome key operations on linked lists:\n- **Insertion**: Adding a new node at the beginning, end, or a specific position in the list.\n- **Deletion**: Removing a node from the beginning, end, or a specific position in the list.\n- **Traversal**: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 1066, 'total_tokens': 1313}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-bb0f2096-c8e8-416c-8ffd-4396e92d2adf-0', usage_metadata={'input_tokens': 1066, 'output_tokens': 247, 'total_tokens': 1313}),
#   HumanMessage(content='Give me a problem in linked lists', id='2903ac9b-af1c-48a5-bf02-48ebbbdcfc09'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FMQuznLDk2Loil0b6FCAapVS', 'function': {'arguments': '{"input_query":"Give me a problem in linked lists","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists"]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 295, 'prompt_tokens': 1327, 'total_tokens': 1622}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-57e21ed6-2c3b-4094-b4a6-0f175fd71a8b-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give me a problem in linked lists', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', 'Give me a problem in linked lists', 'Give me a problem in linked lists', 'Assistant: \n# Definition for singly-linked list.\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n    ']}, 'id': 'call_FMQuznLDk2Loil0b6FCAapVS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1327, 'output_tokens': 295, 'total_tokens': 1622}),
#   ToolMessage(content="return_values={'output': '\\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    '} log='\\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ' session_id='4e59a571-8fe7-46a5-829c-b27445fa2d26'", name='interact_with_agent', id='07552b42-464b-4792-9813-36ad468e4766', tool_call_id='call_FMQuznLDk2Loil0b6FCAapVS'),
#   AIMessage(content="Here's a problem for you based on linked lists:\n\n### Problem: Reverse a Linked List\n\n**Description:**\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\n\n**Example:**\n```\nInput: head = [1, 2, 3, 4, 5]\nOutput: [5, 4, 3, 2, 1]\n```\n\n**Definition for singly-linked list:**\n```python\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n```\n\n### Solution Skeleton:\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\n\n```python\ndef reverseList(head: ListNode) -> ListNode:\n    prev = None\n    curr = head\n\n    while curr is not None:\n        next_temp = curr.next\n        curr.next = prev\n        prev = curr\n        curr = next_temp\n\n    return prev\n```\n\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases.", response_metadata={'token_usage': {'completion_tokens': 245, 'prompt_tokens': 1810, 'total_tokens': 2055}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-4f5ba31b-fefb-43ce-9b52-86c10b8126a7-0', usage_metadata={'input_tokens': 1810, 'output_tokens': 245, 'total_tokens': 2055}),
#   HumanMessage(content='Give a hint', id='12365de3-e6de-4b30-ba11-1e661c5a9b49'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_5klRDWg7h6Ukt0eAScEKXXba', 'function': {'arguments': '{"input_query":"Give a hint for reversing a linked list","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists","Give me a problem in linked lists","Assistant: \\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ","Here\'s a problem for you based on linked lists:\\n\\n### Problem: Reverse a Linked List\\n\\n**Description:**\\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\\n\\n**Example:**\\n```\\nInput: head = [1, 2, 3, 4, 5]\\nOutput: [5, 4, 3, 2, 1]\\n```\\n\\n**Definition for singly-linked list:**\\n```python\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n```\\n\\n### Solution Skeleton:\\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\\n\\n```python\\ndef reverseList(head: ListNode) -> ListNode:\\n    prev = None\\n    curr = head\\n\\n    while curr is not None:\\n        next_temp = curr.next\\n        curr.next = prev\\n        prev = curr\\n        curr = next_temp\\n\\n    return prev\\n```\\n\\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases."]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 623, 'prompt_tokens': 2065, 'total_tokens': 2688}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ff5b6cf1-b6d8-46f9-ae73-90dba8ff5f6c-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give a hint for reversing a linked list', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to ...
#   ToolMessage(content="return_values={'output': 'The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.'} log='The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.' session_id='924c1ed4-11c1-43d5-b6e1-56d20d43c182'", name='interact_with_agent', id='310e95ea-a311-4456-8a11-400cde014594', tool_call_id='call_5klRDWg7h6Ukt0eAScEKXXba'),
#   AIMessage(content='The key idea is to maintain three pointers: `prev` (initially `None`), `curr` (initially `head`), and `next` (initially `curr.next`). Then we iterate through the list, updating the `next` pointer of the current node to point to the previous node, and moving the `prev` and `curr` pointers one step forward. At the end, we return `prev` as the new head of the reversed list.', response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 2981, 'total_tokens': 3079}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-77369fcc-c92b-4df0-957b-27c03881de26-0', usage_metadata={'input_tokens': 2981, 'output_tokens': 98, 'total_tokens': 3079}),
#   HumanMessage(content='Give me a video which explains it', id='ef3af168-40ab-424e-8812-73b2b66c6dd6'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_giYt4HXKHJsH1rqiM0Lrf4VQ', 'function': {'arguments': '{"input_data":"video explanation for reversing a linked list"}', 'name': 'search_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 3093, 'total_tokens': 3114}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-af213c9f-febf-473d-9a12-50b0ffa3170b-0', tool_calls=[{'name': 'search_tool', 'args': {'input_data': 'video explanation for reversing a linked list'}, 'id': 'call_giYt4HXKHJsH1rqiM0Lrf4VQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3093, 'output_tokens': 21, 'total_tokens': 3114}),
#   ToolMessage(content="[snippet: This video is part of the Linked List section in the GFG SDE Sheet. In this video, we are given a linked list of N nodes. The task is to reverse this list. Example : Input: LinkedList: 1->2->3->4->5->6 Output: 6 5 4 3 2 1 Explanation: After reversing the list, elements are 6->5->4->3->2->1. Do check out:-, title: Reverse a Linked list - GeeksforGeeks | Videos, link: https://www.geeksforgeeks.org/videos/reverse-a-linked-list/], [snippet: Given pointer to the head node of a linked list, the task is to reverse the linked list. We need to reverse the list by changing the links between nodes. Examples: Input: Head of following linked list. 1->2->3->4->NULL. Output: Linked list should be changed to,, title: Reversing a linked list - GeeksforGeeks | Videos, link: https://www.geeksforgeeks.org/videos/reversing-a-linked-list/], [snippet: Write a program to reverse the given Doubly Linked List. See below diagrams for example. (a) Original Doubly Linked List (b) Reversed Doubly Linked List Approach: In the previous post, doubly linked list is being reversed by swapping prev and next pointers for all nodes, changing prev of the head (or start) and then changing the head pointer in the, title: Reverse a Linked List - GeeksforGeeks, link: https://www.geeksforgeeks.org/reverse-a-linked-list/], [snippet: Unlock the secrets to reversing a linked list with our comprehensive tutorial! Whether you're prepping for a crucial tech interview or just looking to enhanc..., title: Master the Art of Reversing a Linked List - Step-by-Step Tutorial, link: https://m.youtube.com/watch?v=9EWbV3FhsFY]", name='search_tool', id='7ee9a70c-2af7-4938-a190-692bdaee01ee', tool_call_id='call_giYt4HXKHJsH1rqiM0Lrf4VQ'),
#   AIMessage(content='Here is a video that explains how to reverse a linked list:\n\n[Master the Art of Reversing a Linked List - Step-by-Step Tutorial](https://m.youtube.com/watch?v=9EWbV3FhsFY)\n\nThis tutorial will guide you through the process step-by-step.', response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 3537, 'total_tokens': 3597}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-c1db19b8-7a03-4a17-86fa-8f921eeb9bc4-0', usage_metadata={'input_tokens': 3537, 'output_tokens': 60, 'total_tokens': 3597}),
#   HumanMessage(content='Give me a problem in linked lists', id='e15370a8-789d-4e10-9f1b-7fbb62937594'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_lc2OZaDq38TbyWOqcHht2SmQ', 'function': {'arguments': '{"input_query":"Give me another problem in linked lists","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists","Give me a problem in linked lists","Assistant: \\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ","Here\'s a problem for you based on linked lists:\\n\\n### Problem: Reverse a Linked List\\n\\n**Description:**\\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\\n\\n**Example:**\\n```\\nInput: head = [1, 2, 3, 4, 5]\\nOutput: [5, 4, 3, 2, 1]\\n```\\n\\n**Definition for singly-linked list:**\\n```python\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n```\\n\\n### Solution Skeleton:\\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\\n\\n```python\\ndef reverseList(head: ListNode) -> ListNode:\\n    prev = None\\n    curr = head\\n\\n    while curr is not None:\\n        next_temp = curr.next\\n        curr.next = prev\\n        prev = curr\\n        curr = next_temp\\n\\n    return prev\\n```\\n\\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases.","Give a hint for reversing a linked list","Assistant: The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.","Give me a video which explains it","Assistant to=functions.search_tool: Video explanation for reversing a linked list","Here is a video that explains how to reverse a linked list:\\n\\n[Master the Art of Reversing a Linked List - Step-by-Step Tutorial](https://m.youtube.com/watch?v=9EWbV3FhsFY)\\n\\nThis tutorial will guide you through the process step-by-step.","Give me a problem in linked lists"]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 804, 'prompt_tokens': 3611, 'total_tokens': 4415}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-afe2528f-c2a0-47f9-9142-692d75fa5af3-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give me another problem in linked lists', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each e ...
#   ToolMessage(content="return_values={'output': 'Could you please provide me with another linked list problem for a coding interview preparation? I would like the problem statement, examples of how it should work, and the necessary code definitions like the structure of a linked list node.'} log='Could you please provide me with another linked list problem for a coding interview preparation? I would like the problem statement, examples of how it should work, and the necessary code definitions like the structure of a linked list node.' session_id='c80e0373-0b21-4a97-85bd-91cf15ed4dc0'", name='interact_with_agent', id='055d0164-3517-4d28-9a48-1feea895203b', tool_call_id='call_lc2OZaDq38TbyWOqcHht2SmQ'),
#   AIMessage(content="### Problem: Detect a Cycle in a Linked List\n\n**Description:**\nGiven the head of a singly linked list, determine if the linked list has a cycle in it. A cycle occurs when a node's next pointer points back to a previous node in the list, creating a loop.\n\n**Example 1:**\n```\nInput: head = [3, 2, 0, -4], pos = 1\nOutput: true\nExplanation: There is a cycle in the linked list where the tail connects to the second node.\n```\n\n**Example 2:**\n```\nInput: head = [1, 2], pos = 0\nOutput: true\nExplanation: There is a cycle in the linked list where the tail connects to the first node.\n```\n\n**Example 3:**\n```\nInput: head = [1], pos = -1\nOutput: false\nExplanation: There is no cycle in the linked list.\n```\n\n**Definition for singly-linked list:**\n```python\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n```\n\n### Solution Skeleton:\nYou need to create a function that takes the head of the linked list and returns a boolean indicating whether there is a cycle in the list.\n\n```python\ndef hasCycle(head: ListNode) -> bool:\n    slow = head\n    fast = head\n\n    while fast is not None and fast.next is not None:\n        slow = slow.next\n        fast = fast.next.next\n        \n        if slow == fast:\n            return True\n\n    return False\n```\n\nThis function uses Floyd’s Cycle-Finding Algorithm, also known as the Tortoise and the Hare algorithm, to detect a cycle. You can solve this problem and test it with different input cases.", response_metadata={'token_usage': {'completion_tokens': 379, 'prompt_tokens': 4605, 'total_tokens': 4984}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-e57522ad-4d96-4f38-b403-c32c3d960698-0', usage_metadata={'input_tokens': 4605, 'output_tokens': 379, 'total_tokens': 4984})]}

# %%
messages3 = pipeline('Give a hint', message_history)
message_history += messages3
messages3
# Out:
# return_values={'output': 'The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.'} log='The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.' session_id='924c1ed4-11c1-43d5-b6e1-56d20d43c182'
# {'messages': [HumanMessage(content='Please explain linked lists to me', id='406464c1-a8f5-411c-aa2f-9d74260c1ce5'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'function': {'arguments': '{"input_query":"Please explain linked lists to me","chat_history":[]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 230, 'total_tokens': 256}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d525fab9-74c2-403a-bd07-ee8c91cd1fcc-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Please explain linked lists to me', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.']}, 'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 230, 'output_tokens': 26, 'total_tokens': 256}),
#   ToolMessage(content="return_values={'output': 'A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.'} log='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.' session_id='83f1a098-6ec5-4077-94c2-503b9dd1622b'", name='interact_with_agent', id='82d9635d-64b0-4d5e-a93b-6c2cbe8844bb', tool_call_id='call_P2gVcpaq5CkBD1QeQjpObCSw'),
#   AIMessage(content='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. **Data**: The value or information that the node stores.\n2. **Next**: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\n```python\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n```\n\nSome key operations on linked lists:\n- **Insertion**: Adding a new node at the beginning, end, or a specific position in the list.\n- **Deletion**: Removing a node from the beginning, end, or a specific position in the list.\n- **Traversal**: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 1066, 'total_tokens': 1313}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-bb0f2096-c8e8-416c-8ffd-4396e92d2adf-0', usage_metadata={'input_tokens': 1066, 'output_tokens': 247, 'total_tokens': 1313}),
#   HumanMessage(content='Give me a problem in linked lists', id='2903ac9b-af1c-48a5-bf02-48ebbbdcfc09'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FMQuznLDk2Loil0b6FCAapVS', 'function': {'arguments': '{"input_query":"Give me a problem in linked lists","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists"]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 295, 'prompt_tokens': 1327, 'total_tokens': 1622}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-57e21ed6-2c3b-4094-b4a6-0f175fd71a8b-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give me a problem in linked lists', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', 'Give me a problem in linked lists', 'Give me a problem in linked lists', 'Assistant: \n# Definition for singly-linked list.\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n    ']}, 'id': 'call_FMQuznLDk2Loil0b6FCAapVS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1327, 'output_tokens': 295, 'total_tokens': 1622}),
#   ToolMessage(content="return_values={'output': '\\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    '} log='\\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ' session_id='4e59a571-8fe7-46a5-829c-b27445fa2d26'", name='interact_with_agent', id='07552b42-464b-4792-9813-36ad468e4766', tool_call_id='call_FMQuznLDk2Loil0b6FCAapVS'),
#   AIMessage(content="Here's a problem for you based on linked lists:\n\n### Problem: Reverse a Linked List\n\n**Description:**\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\n\n**Example:**\n```\nInput: head = [1, 2, 3, 4, 5]\nOutput: [5, 4, 3, 2, 1]\n```\n\n**Definition for singly-linked list:**\n```python\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n```\n\n### Solution Skeleton:\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\n\n```python\ndef reverseList(head: ListNode) -> ListNode:\n    prev = None\n    curr = head\n\n    while curr is not None:\n        next_temp = curr.next\n        curr.next = prev\n        prev = curr\n        curr = next_temp\n\n    return prev\n```\n\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases.", response_metadata={'token_usage': {'completion_tokens': 245, 'prompt_tokens': 1810, 'total_tokens': 2055}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-4f5ba31b-fefb-43ce-9b52-86c10b8126a7-0', usage_metadata={'input_tokens': 1810, 'output_tokens': 245, 'total_tokens': 2055}),
#   HumanMessage(content='Give a hint', id='12365de3-e6de-4b30-ba11-1e661c5a9b49'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_5klRDWg7h6Ukt0eAScEKXXba', 'function': {'arguments': '{"input_query":"Give a hint for reversing a linked list","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists","Give me a problem in linked lists","Assistant: \\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ","Here\'s a problem for you based on linked lists:\\n\\n### Problem: Reverse a Linked List\\n\\n**Description:**\\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\\n\\n**Example:**\\n```\\nInput: head = [1, 2, 3, 4, 5]\\nOutput: [5, 4, 3, 2, 1]\\n```\\n\\n**Definition for singly-linked list:**\\n```python\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n```\\n\\n### Solution Skeleton:\\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\\n\\n```python\\ndef reverseList(head: ListNode) -> ListNode:\\n    prev = None\\n    curr = head\\n\\n    while curr is not None:\\n        next_temp = curr.next\\n        curr.next = prev\\n        prev = curr\\n        curr = next_temp\\n\\n    return prev\\n```\\n\\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases."]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 623, 'prompt_tokens': 2065, 'total_tokens': 2688}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ff5b6cf1-b6d8-46f9-ae73-90dba8ff5f6c-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give a hint for reversing a linked list', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to ...
#   ToolMessage(content="return_values={'output': 'The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.'} log='The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.' session_id='924c1ed4-11c1-43d5-b6e1-56d20d43c182'", name='interact_with_agent', id='310e95ea-a311-4456-8a11-400cde014594', tool_call_id='call_5klRDWg7h6Ukt0eAScEKXXba'),
#   AIMessage(content='The key idea is to maintain three pointers: `prev` (initially `None`), `curr` (initially `head`), and `next` (initially `curr.next`). Then we iterate through the list, updating the `next` pointer of the current node to point to the previous node, and moving the `prev` and `curr` pointers one step forward. At the end, we return `prev` as the new head of the reversed list.', response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 2981, 'total_tokens': 3079}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-77369fcc-c92b-4df0-957b-27c03881de26-0', usage_metadata={'input_tokens': 2981, 'output_tokens': 98, 'total_tokens': 3079})]}

# %%
messages4 = pipeline('Give me a video which explains it', message_history)
message_history += messages4
messages4
# Out:
# {'messages': [HumanMessage(content='Please explain linked lists to me', id='406464c1-a8f5-411c-aa2f-9d74260c1ce5'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'function': {'arguments': '{"input_query":"Please explain linked lists to me","chat_history":[]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 230, 'total_tokens': 256}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d525fab9-74c2-403a-bd07-ee8c91cd1fcc-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Please explain linked lists to me', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.']}, 'id': 'call_P2gVcpaq5CkBD1QeQjpObCSw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 230, 'output_tokens': 26, 'total_tokens': 256}),
#   ToolMessage(content="return_values={'output': 'A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.'} log='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.' session_id='83f1a098-6ec5-4077-94c2-503b9dd1622b'", name='interact_with_agent', id='82d9635d-64b0-4d5e-a93b-6c2cbe8844bb', tool_call_id='call_P2gVcpaq5CkBD1QeQjpObCSw'),
#   AIMessage(content='A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. **Data**: The value or information that the node stores.\n2. **Next**: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\n```python\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n```\n\nSome key operations on linked lists:\n- **Insertion**: Adding a new node at the beginning, end, or a specific position in the list.\n- **Deletion**: Removing a node from the beginning, end, or a specific position in the list.\n- **Traversal**: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 1066, 'total_tokens': 1313}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-bb0f2096-c8e8-416c-8ffd-4396e92d2adf-0', usage_metadata={'input_tokens': 1066, 'output_tokens': 247, 'total_tokens': 1313}),
#   HumanMessage(content='Give me a problem in linked lists', id='2903ac9b-af1c-48a5-bf02-48ebbbdcfc09'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FMQuznLDk2Loil0b6FCAapVS', 'function': {'arguments': '{"input_query":"Give me a problem in linked lists","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists"]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 295, 'prompt_tokens': 1327, 'total_tokens': 1622}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-57e21ed6-2c3b-4094-b4a6-0f175fd71a8b-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give me a problem in linked lists', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to perform some operation.\n\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.', 'Give me a problem in linked lists', 'Give me a problem in linked lists', 'Assistant: \n# Definition for singly-linked list.\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n    ']}, 'id': 'call_FMQuznLDk2Loil0b6FCAapVS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1327, 'output_tokens': 295, 'total_tokens': 1622}),
#   ToolMessage(content="return_values={'output': '\\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    '} log='\\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ' session_id='4e59a571-8fe7-46a5-829c-b27445fa2d26'", name='interact_with_agent', id='07552b42-464b-4792-9813-36ad468e4766', tool_call_id='call_FMQuznLDk2Loil0b6FCAapVS'),
#   AIMessage(content="Here's a problem for you based on linked lists:\n\n### Problem: Reverse a Linked List\n\n**Description:**\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\n\n**Example:**\n```\nInput: head = [1, 2, 3, 4, 5]\nOutput: [5, 4, 3, 2, 1]\n```\n\n**Definition for singly-linked list:**\n```python\nclass ListNode:\n    def __init__(self, val=0, next=None):\n        self.val = val\n        self.next = next\n```\n\n### Solution Skeleton:\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\n\n```python\ndef reverseList(head: ListNode) -> ListNode:\n    prev = None\n    curr = head\n\n    while curr is not None:\n        next_temp = curr.next\n        curr.next = prev\n        prev = curr\n        curr = next_temp\n\n    return prev\n```\n\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases.", response_metadata={'token_usage': {'completion_tokens': 245, 'prompt_tokens': 1810, 'total_tokens': 2055}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-4f5ba31b-fefb-43ce-9b52-86c10b8126a7-0', usage_metadata={'input_tokens': 1810, 'output_tokens': 245, 'total_tokens': 2055}),
#   HumanMessage(content='Give a hint', id='12365de3-e6de-4b30-ba11-1e661c5a9b49'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_5klRDWg7h6Ukt0eAScEKXXba', 'function': {'arguments': '{"input_query":"Give a hint for reversing a linked list","chat_history":["Please explain linked lists to me","Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\\n\\nEach node in a linked list has two parts:\\n1. Data: The value or information that the node stores.\\n2. Next: A pointer or reference to the next node in the list.\\n\\nThe basic structure of a node in a singly linked list can be represented as:\\n\\nclass Node:\\n    def __init__(self, data):\\n        self.data = data\\n        self.next = None\\n\\nSome key operations on linked lists:\\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\\n- Traversal: Visiting each node in the list to perform some operation.\\n\\nLinked lists have some advantages over arrays, such as dynamic size and efficient insertion/deletion operations. However, random access is not efficient in linked lists compared to arrays.","Give me a problem in linked lists","Give me a problem in linked lists","Assistant: \\n# Definition for singly-linked list.\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n    ","Here\'s a problem for you based on linked lists:\\n\\n### Problem: Reverse a Linked List\\n\\n**Description:**\\nGiven the head of a singly linked list, reverse the list, and return the reversed list.\\n\\n**Example:**\\n```\\nInput: head = [1, 2, 3, 4, 5]\\nOutput: [5, 4, 3, 2, 1]\\n```\\n\\n**Definition for singly-linked list:**\\n```python\\nclass ListNode:\\n    def __init__(self, val=0, next=None):\\n        self.val = val\\n        self.next = next\\n```\\n\\n### Solution Skeleton:\\nYou need to create a function that takes the head of the linked list and returns the head of the reversed linked list.\\n\\n```python\\ndef reverseList(head: ListNode) -> ListNode:\\n    prev = None\\n    curr = head\\n\\n    while curr is not None:\\n        next_temp = curr.next\\n        curr.next = prev\\n        prev = curr\\n        curr = next_temp\\n\\n    return prev\\n```\\n\\nThis function uses an iterative approach to reverse the linked list. You can solve this problem and then test it with different input cases."]}', 'name': 'interact_with_agent'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 623, 'prompt_tokens': 2065, 'total_tokens': 2688}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ff5b6cf1-b6d8-46f9-ae73-90dba8ff5f6c-0', tool_calls=[{'name': 'interact_with_agent', 'args': {'input_query': 'Give a hint for reversing a linked list', 'chat_history': ['Please explain linked lists to me', 'Assistant: A linked list is a linear data structure where each element (called a node) contains a value and a reference (or pointer) to the next node in the sequence. The first node is called the head, and the last node points to null to mark the end of the list.\n\nEach node in a linked list has two parts:\n1. Data: The value or information that the node stores.\n2. Next: A pointer or reference to the next node in the list.\n\nThe basic structure of a node in a singly linked list can be represented as:\n\nclass Node:\n    def __init__(self, data):\n        self.data = data\n        self.next = None\n\nSome key operations on linked lists:\n- Insertion: Adding a new node at the beginning, end, or a specific position in the list.\n- Deletion: Removing a node from the beginning, end, or a specific position in the list.\n- Traversal: Visiting each node in the list to ...
#   ToolMessage(content="return_values={'output': 'The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.'} log='The key idea is to maintain three pointers: prev (initially None), curr (initially head), and next (initially curr.next). Then we iterate through the list, updating the next pointer of the current node to point to the previous node, and moving the prev and curr pointers one step forward. At the end, we return prev as the new head of the reversed list.' session_id='924c1ed4-11c1-43d5-b6e1-56d20d43c182'", name='interact_with_agent', id='310e95ea-a311-4456-8a11-400cde014594', tool_call_id='call_5klRDWg7h6Ukt0eAScEKXXba'),
#   AIMessage(content='The key idea is to maintain three pointers: `prev` (initially `None`), `curr` (initially `head`), and `next` (initially `curr.next`). Then we iterate through the list, updating the `next` pointer of the current node to point to the previous node, and moving the `prev` and `curr` pointers one step forward. At the end, we return `prev` as the new head of the reversed list.', response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 2981, 'total_tokens': 3079}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-77369fcc-c92b-4df0-957b-27c03881de26-0', usage_metadata={'input_tokens': 2981, 'output_tokens': 98, 'total_tokens': 3079}),
#   HumanMessage(content='Give me a video which explains it', id='ef3af168-40ab-424e-8812-73b2b66c6dd6'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_giYt4HXKHJsH1rqiM0Lrf4VQ', 'function': {'arguments': '{"input_data":"video explanation for reversing a linked list"}', 'name': 'search_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 3093, 'total_tokens': 3114}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-af213c9f-febf-473d-9a12-50b0ffa3170b-0', tool_calls=[{'name': 'search_tool', 'args': {'input_data': 'video explanation for reversing a linked list'}, 'id': 'call_giYt4HXKHJsH1rqiM0Lrf4VQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3093, 'output_tokens': 21, 'total_tokens': 3114}),
#   ToolMessage(content="[snippet: This video is part of the Linked List section in the GFG SDE Sheet. In this video, we are given a linked list of N nodes. The task is to reverse this list. Example : Input: LinkedList: 1->2->3->4->5->6 Output: 6 5 4 3 2 1 Explanation: After reversing the list, elements are 6->5->4->3->2->1. Do check out:-, title: Reverse a Linked list - GeeksforGeeks | Videos, link: https://www.geeksforgeeks.org/videos/reverse-a-linked-list/], [snippet: Given pointer to the head node of a linked list, the task is to reverse the linked list. We need to reverse the list by changing the links between nodes. Examples: Input: Head of following linked list. 1->2->3->4->NULL. Output: Linked list should be changed to,, title: Reversing a linked list - GeeksforGeeks | Videos, link: https://www.geeksforgeeks.org/videos/reversing-a-linked-list/], [snippet: Write a program to reverse the given Doubly Linked List. See below diagrams for example. (a) Original Doubly Linked List (b) Reversed Doubly Linked List Approach: In the previous post, doubly linked list is being reversed by swapping prev and next pointers for all nodes, changing prev of the head (or start) and then changing the head pointer in the, title: Reverse a Linked List - GeeksforGeeks, link: https://www.geeksforgeeks.org/reverse-a-linked-list/], [snippet: Unlock the secrets to reversing a linked list with our comprehensive tutorial! Whether you're prepping for a crucial tech interview or just looking to enhanc..., title: Master the Art of Reversing a Linked List - Step-by-Step Tutorial, link: https://m.youtube.com/watch?v=9EWbV3FhsFY]", name='search_tool', id='7ee9a70c-2af7-4938-a190-692bdaee01ee', tool_call_id='call_giYt4HXKHJsH1rqiM0Lrf4VQ'),
#   AIMessage(content='Here is a video that explains how to reverse a linked list:\n\n[Master the Art of Reversing a Linked List - Step-by-Step Tutorial](https://m.youtube.com/watch?v=9EWbV3FhsFY)\n\nThis tutorial will guide you through the process step-by-step.', response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 3537, 'total_tokens': 3597}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-c1db19b8-7a03-4a17-86fa-8f921eeb9bc4-0', usage_metadata={'input_tokens': 3537, 'output_tokens': 60, 'total_tokens': 3597})]}
